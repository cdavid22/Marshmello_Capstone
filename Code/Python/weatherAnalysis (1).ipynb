# %% [markdown]
# # **Weather Data Analysis**
# **The Weather data was obtained from "http://climate.weather.gc.ca". The data from the weather station at the Montreal Airport was used.**

# %%
str_months = []

str_months.append('eng-hourly-01012010-01312010.csv')
str_months.append('eng-hourly-02012010-02282010.csv')
str_months.append('eng-hourly-03012010-03312010.csv')
str_months.append('eng-hourly-04012010-04302010.csv')
str_months.append('eng-hourly-05012010-05312010.csv')
str_months.append('eng-hourly-06012010-06302010.csv')
str_months.append('eng-hourly-07012010-07312010.csv')
str_months.append('eng-hourly-08012010-08312010.csv')
str_months.append('eng-hourly-09012010-09302010.csv')
str_months.append('eng-hourly-10012010-10312010.csv')
str_months.append('eng-hourly-11012010-11302010.csv')
str_months.append('eng-hourly-12012010-12312010.csv')

str_months.append('eng-hourly-01012011-01312011.csv')
str_months.append('eng-hourly-02012011-02282011.csv')
str_months.append('eng-hourly-03012011-03312011.csv')
str_months.append('eng-hourly-04012011-04302011.csv')
str_months.append('eng-hourly-05012011-05312011.csv')
str_months.append('eng-hourly-06012011-06302011.csv')
str_months.append('eng-hourly-07012011-07312011.csv')
str_months.append('eng-hourly-08012011-08312011.csv')
str_months.append('eng-hourly-09012011-09302011.csv')
str_months.append('eng-hourly-10012011-10312011.csv')
str_months.append('eng-hourly-11012011-11302011.csv')
str_months.append('eng-hourly-12012011-12312011.csv')

str_months.append('eng-hourly-01012012-01312012.csv')
str_months.append('eng-hourly-02012012-02292012.csv')
str_months.append('eng-hourly-03012012-03312012.csv')
str_months.append('eng-hourly-04012012-04302012.csv')
str_months.append('eng-hourly-05012012-05312012.csv')
str_months.append('eng-hourly-06012012-06302012.csv')
str_months.append('eng-hourly-07012012-07312012.csv')
str_months.append('eng-hourly-08012012-08312012.csv')
str_months.append('eng-hourly-09012012-09302012.csv')
str_months.append('eng-hourly-10012012-10312012.csv')
str_months.append('eng-hourly-11012012-11302012.csv')
str_months.append('eng-hourly-12012012-12312012.csv')

str_months.append('eng-hourly-01012013-01312013.csv')
str_months.append('eng-hourly-02012013-02282013.csv')
str_months.append('eng-hourly-03012013-03312013.csv')
str_months.append('eng-hourly-04012013-04302013.csv')
str_months.append('eng-hourly-05012013-05312013.csv')
str_months.append('eng-hourly-06012013-06302013.csv')
str_months.append('eng-hourly-07012013-07312013.csv')
str_months.append('eng-hourly-08012013-08312013.csv')
str_months.append('eng-hourly-09012013-09302013.csv')
str_months.append('eng-hourly-10012013-10312013.csv')
str_months.append('eng-hourly-11012013-11302013.csv')
str_months.append('eng-hourly-12012013-12312013.csv')

str_months.append('eng-hourly-01012014-01312014.csv')
str_months.append('eng-hourly-02012014-02282014.csv')
str_months.append('eng-hourly-03012014-03312014.csv')
str_months.append('eng-hourly-04012014-04302014.csv')
str_months.append('eng-hourly-05012014-05312014.csv')
str_months.append('eng-hourly-06012014-06302014.csv')
str_months.append('eng-hourly-07012014-07312014.csv')
str_months.append('eng-hourly-08012014-08312014.csv')
str_months.append('eng-hourly-09012014-09302014.csv')
str_months.append('eng-hourly-10012014-10312014.csv')
str_months.append('eng-hourly-11012014-11302014.csv')
str_months.append('eng-hourly-12012014-12312014.csv')

str_months.append('eng-hourly-01012015-01312015.csv')
str_months.append('eng-hourly-02012015-02282015.csv')
str_months.append('eng-hourly-03012015-03312015.csv')
str_months.append('eng-hourly-04012015-04302015.csv')
str_months.append('eng-hourly-05012015-05312015.csv')
str_months.append('eng-hourly-06012015-06302015.csv')
str_months.append('eng-hourly-07012015-07312015.csv')
str_months.append('eng-hourly-08012015-08312015.csv')
str_months.append('eng-hourly-09012015-09302015.csv')
str_months.append('eng-hourly-10012015-10312015.csv')
str_months.append('eng-hourly-11012015-11302015.csv')
str_months.append('eng-hourly-12012015-12312015.csv')

str_months.append('eng-hourly-01012016-01312016.csv')
str_months.append('eng-hourly-02012016-02292016.csv')
str_months.append('eng-hourly-03012016-03312016.csv')
str_months.append('eng-hourly-04012016-04302016.csv')
str_months.append('eng-hourly-05012016-05312016.csv')
str_months.append('eng-hourly-06012016-06302016.csv')
str_months.append('eng-hourly-07012016-07312016.csv')
str_months.append('eng-hourly-08012016-08312016.csv')
str_months.append('eng-hourly-09012016-09302016.csv')
str_months.append('eng-hourly-10012016-10312016.csv')
str_months.append('eng-hourly-11012016-11302016.csv')
str_months.append('eng-hourly-12012016-12312016.csv')

str_months.append('eng-hourly-01012017-01312017.csv')
str_months.append('eng-hourly-02012017-02282017.csv')
str_months.append('eng-hourly-03012017-03312017.csv')
str_months.append('eng-hourly-04012017-04302017.csv')
str_months.append('eng-hourly-05012017-05312017.csv')
str_months.append('eng-hourly-06012017-06302017.csv')
str_months.append('eng-hourly-07012017-07312017.csv')
str_months.append('eng-hourly-08012017-08312017.csv')
str_months.append('eng-hourly-09012017-09302017.csv')
str_months.append('eng-hourly-10012017-10312017.csv')
str_months.append('eng-hourly-11012017-11302017.csv')
str_months.append('eng-hourly-12012017-12312017.csv')

# %%
df_months = [pd.read_csv(file_name, header=13) for file_name in str_months]
weather = pd.concat(df_months)

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70128 entries, 0 to 743
# Data columns (total 24 columns):
# Date/Time              70128 non-null object
# Year                   70128 non-null int64
# Month                  70128 non-null int64
# Day                    70128 non-null int64
# Time                   70128 non-null object
# Temp (°C)              69574 non-null float64
# Temp Flag              4 non-null object
# Dew Point Temp (°C)    69578 non-null float64
# Dew Point Temp Flag    0 non-null float64
# Rel Hum (%)            69578 non-null float64
# Rel Hum Flag           0 non-null float64
# Wind Dir (10s deg)     68356 non-null float64
# Wind Dir Flag          34 non-null object
# Wind Spd (km/h)        69578 non-null float64
# Wind Spd Flag          22 non-null object
# Visibility (km)        26300 non-null float64
# Visibility Flag        0 non-null float64
# Stn Press (kPa)        69575 non-null float64
# Stn Press Flag         3 non-null object
# ...

# %%
# dropping all the fields that we are not interested in as they mostrly contail null values.
weather = weather.drop(['Year','Month','Day','Time','Wind Dir Flag','Wind Spd Flag','Visibility (km)','Visibility Flag','Stn Press Flag','Hmdx','Hmdx Flag','Wind Chill Flag','Weather'],axis=1)

# %%
weather.drop(['Temp Flag','Dew Point Temp Flag','Rel Hum Flag', 'Wind Chill'],axis=1,inplace=True)

# %%
wdh= weather['Date/Time'].str.split(':',expand=True)
weather['wdateHr'] = wdh[0]

# %%
weather.head()
# Out:
#           Date/Time  Temp (°C)  Dew Point Temp (°C)  Rel Hum (%)  \
# 0  2010-01-01 00:00       -3.8                 -5.0         91.0
# 1  2010-01-01 01:00       -4.7                 -5.4         95.0
# 2  2010-01-01 02:00       -4.6                 -5.3         95.0
# 3  2010-01-01 03:00       -4.6                 -5.4         94.0
# 4  2010-01-01 04:00       -4.9                 -5.7         94.0
#
#    Wind Dir (10s deg)  Wind Spd (km/h)  Stn Press (kPa)  Wind Chill  \
# 0                 4.0             11.0           101.11        -8.0
# 1                 3.0             15.0           101.05       -10.0
# 2                 3.0             15.0           101.05       -10.0
# 3                 3.0             15.0           101.02       -10.0
# 4                 3.0             15.0           100.99       -10.0
#
#          wdateHr
# 0  2010-01-01 00
# 1  2010-01-01 01
# 2  2010-01-01 02
# 3  2010-01-01 03
# 4  2010-01-01 04

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70128 entries, 0 to 743
# Data columns (total 9 columns):
# Date/Time              70128 non-null object
# Temp (°C)              69574 non-null float64
# Dew Point Temp (°C)    69578 non-null float64
# Rel Hum (%)            69578 non-null float64
# Wind Dir (10s deg)     68356 non-null float64
# Wind Spd (km/h)        69578 non-null float64
# Stn Press (kPa)        69575 non-null float64
# Wind Chill             18033 non-null float64
# wdateHr                70128 non-null object
# dtypes: float64(7), object(2)
# memory usage: 5.4+ MB

# %%
weather.to_csv('weather_combined.csv')

# %%
weather['creation_datetime'] = pd.to_datetime(weather['Date/Time'])
weather = weather.set_index('creation_datetime')
weather.head()
# Out:
#                      Unnamed: 0         Date/Time  Temp (°C)  \
# creation_datetime
# 2010-01-01 00:00:00           0  2010-01-01 00:00       -3.8
# 2010-01-01 01:00:00           1  2010-01-01 01:00       -4.7
# 2010-01-01 02:00:00           2  2010-01-01 02:00       -4.6
# 2010-01-01 03:00:00           3  2010-01-01 03:00       -4.6
# 2010-01-01 04:00:00           4  2010-01-01 04:00       -4.9
#
#                      Dew Point Temp (°C)  Rel Hum (%)  Wind Dir (10s deg)  \
# creation_datetime
# 2010-01-01 00:00:00                 -5.0         91.0                 4.0
# 2010-01-01 01:00:00                 -5.4         95.0                 3.0
# 2010-01-01 02:00:00                 -5.3         95.0                 3.0
# 2010-01-01 03:00:00                 -5.4         94.0                 3.0
# 2010-01-01 04:00:00                 -5.7         94.0                 3.0
#
#                      Wind Spd (km/h)  Stn Press (kPa)        wdateHr
# creation_datetime
# ...

# %%
w_10 = weather['2010-01-01':'2010-12-31']
w_11 = weather['2011-01-01':'2011-12-31']
w_12 = weather['2012-01-01':'2012-12-31']
w_13 = weather['2013-01-01':'2013-12-31']
w_14 = weather['2014-01-01':'2014-12-31']
w_15 = weather['2015-01-01':'2015-12-31']
w_16 = weather['2016-01-01':'2016-12-31']
w_17 = weather['2017-01-01':'2017-12-31']

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,50))
plt.subplot(8, 2, 1)
plt.hist(w_10['Temp (°C)'],bins=100)
plt.xlabel("Temperature")
plt.ylabel("No of Hours")
plt.title("2010")
plt.subplot(8, 2, 2)
plt.hist(w_11['Temp (°C)'],bins=100)
plt.xlabel("Temperature")
plt.ylabel("No of Hours")
plt.title("2011")
plt.subplot(8, 2, 3)
plt.hist(w_12['Temp (°C)'],bins=100)
plt.xlabel("Temperature")
plt.ylabel("No of Hours")
plt.title("2012")
plt.subplot(8, 2, 4)
plt.hist(w_13['Temp (°C)'],bins=100)
plt.xlabel("Temperature")
plt.ylabel("No of Hours")
plt.title("2013")
plt.subplot(8, 2, 5)
plt.hist(w_14['Temp (°C)'],bins=100)
plt.xlabel("Temperature")
plt.ylabel("No of Hours")
plt.title("2014")
plt.subplot(8, 2, 6)
plt.hist(w_15['Temp (°C)'],bins=100)
plt.xlabel("Temperature")
plt.ylabel("No of Hours")
plt.title("2015")
plt.subplot(8, 2, 7)
plt.hist(w_16['Temp (°C)'],bins=100)
plt.xlabel("Temperature")
plt.ylabel("No of Hours")
plt.title("2016")
plt.subplot(8, 2, 8)
plt.hist(w_17['Temp (°C)'],bins=100)
plt.xlabel("Temperature")
plt.ylabel("No of Hours")
plt.title("2017")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py:780: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py:781: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
plt.hist(weather['Temp (°C)'],bins=100)
plt.xlabel("Temperature")
plt.ylabel("No of Hours")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py:780: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py:781: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,50))
plt.subplot(8, 2, 1)
plt.hist(w_10['Rel Hum (%)'],bins=100)
plt.xlabel("Relative Humidity (%)")
plt.ylabel("No of Hours")
plt.title("2010")
plt.subplot(8, 2, 2)
plt.hist(w_11['Rel Hum (%)'],bins=100)
plt.xlabel("Relative Humidity (%)")
plt.ylabel("No of Hours")
plt.title("2011")
plt.subplot(8, 2, 3)
plt.hist(w_12['Rel Hum (%)'],bins=100)
plt.xlabel("Relative Humidity (%)")
plt.ylabel("No of Hours")
plt.title("2012")
plt.subplot(8, 2, 4)
plt.hist(w_13['Rel Hum (%)'],bins=100)
plt.xlabel("Relative Humidity (%)")
plt.ylabel("No of Hours")
plt.title("2013")
plt.subplot(8, 2, 5)
plt.hist(w_14['Rel Hum (%)'],bins=100)
plt.xlabel("Relative Humidity (%)")
plt.ylabel("No of Hours")
plt.title("2014")
plt.subplot(8, 2, 6)
plt.hist(w_15['Rel Hum (%)'],bins=100)
plt.xlabel("Relative Humidity (%)")
plt.ylabel("No of Hours")
plt.title("2015")
plt.subplot(8, 2, 7)
plt.hist(w_16['Rel Hum (%)'],bins=100)
plt.xlabel("Relative Humidity (%)")
plt.ylabel("No of Hours")
plt.title("2016")
plt.subplot(8, 2, 8)
plt.hist(w_17['Rel Hum (%)'],bins=100)
plt.xlabel("Relative Humidity (%)")
plt.ylabel("No of Hours")
plt.title("2017")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py:780: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py:781: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
plt.hist(weather['Rel Hum (%)'],bins=100)
plt.xlabel("Rel Hum (%)")
plt.ylabel("No of Hours")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py:780: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py:781: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
plt.figure(figsize=(15,30))
plt.subplot(8, 2, 1)
plt.hist(w_10['Stn Press (kPa)'],bins=100,color='blue',alpha=0.5)
plt.xlabel("Temperature")
plt.ylabel("No of Hours")
plt.subplot(8, 2, 2)
plt.hist(w_11['Stn Press (kPa)'],bins=100,color='blue',alpha=0.5)
plt.xlabel("Temperature")
plt.ylabel("No of Hours")
plt.subplot(8, 2, 3)
plt.hist(w_12['Stn Press (kPa)'],bins=100,color='blue',alpha=0.5)
plt.xlabel("Temperature")
plt.ylabel("No of Hours")
plt.subplot(8, 2, 4)
plt.hist(w_13['Stn Press (kPa)'],bins=100,color='blue',alpha=0.5)
plt.xlabel("Temperature")
plt.ylabel("No of Hours")
plt.subplot(8, 2, 5)
plt.hist(w_14['Stn Press (kPa)'],bins=100,color='blue',alpha=0.5)
plt.xlabel("Temperature")
plt.ylabel("No of Hours")
plt.subplot(8, 2, 6)
plt.hist(w_15['Stn Press (kPa)'],bins=100,color='blue',alpha=0.5)
plt.xlabel("Temperature")
plt.ylabel("No of Hours")
plt.subplot(8, 2, 7)
plt.hist(w_16['Stn Press (kPa)'],bins=100,color='blue',alpha=0.5)
plt.xlabel("Temperature")
plt.ylabel("No of Hours")
plt.subplot(8, 2, 8)
plt.hist(w_17['Stn Press (kPa)'],bins=100,color='blue',alpha=0.5)
plt.xlabel("Temperature")
plt.ylabel("No of Hours")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py:780: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py:781: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
plt.hist(weather['Stn Press (kPa)'],bins=100,color='blue',alpha=0.5)
plt.xlabel("Temperature")
plt.ylabel("No of Hours")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py:780: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py:781: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
