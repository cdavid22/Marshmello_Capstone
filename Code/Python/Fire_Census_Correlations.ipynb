# %% [markdown]
# # **SIM and Census Correlation Analysis**

# %%
#Importing all the relevant libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import calendar
import seaborn as sns

# %%
#Import SIM data and filter out only 2016 data
fire_df = pd.read_csv('donneesouvertes-interventions-sim (2).csv')
fire_df['creation_datetime'] = pd.to_datetime(fire_df['creation_date_time'])
fire_df = fire_df.set_index('creation_datetime')
fire_df = fire_df['2016-01-01' :'2016-12-31']
fire_df.head()
# Out:
#                      incident_nbr   creation_date_time incident_type_desc  \
# creation_datetime
# 2016-01-01 00:00:50             1  2016-01-01 00:00:50  Premier répondant
# 2016-01-01 00:02:42             2  2016-01-01 00:02:42  Premier répondant
# 2016-01-01 00:05:48             3  2016-01-01 00:05:48  Premier répondant
# 2016-01-01 00:08:24             4  2016-01-01 00:08:24  Premier répondant
# 2016-01-01 00:09:11             5  2016-01-01 00:09:11  Premier répondant
#
#                     description_groupe  caserne       nom_ville  \
# creation_datetime
# 2016-01-01 00:00:50  Premier répondant       77  Montréal-Ouest
# 2016-01-01 00:02:42  Premier répondant       25        Montréal
# 2016-01-01 00:05:48  Premier répondant       17        Montréal
# 2016-01-01 00:08:24  Premier répondant       25        Montréal
# 2016-01-01 00:09:11  Premier répondant       20        Montréal
#
#                         nom_arrond  division   latitude  longitude  \
# creation_datetime
# 2016-01-01 00:00:50    Indéterminé         4  45.452849 -73.645278
# 2016-01-01 00:02:42    Ville-Marie         6  45.498051 -73.577476
# 2016-01-01 00:05:48  Montréal-Nord         8  45.584992 -73.629010
# 2016-01-01 00:08:24    Ville-Marie         6  45.497394 -73.578090
# 2016-01-01 00:09:11    Ville-Marie         6  45.517014 -73.557496
#
#                      nombre_unites
# creation_datetime
# 2016-01-01 00:00:50            1.0
# 2016-01-01 00:02:42            1.0
# 2016-01-01 00:05:48            1.0
# 2016-01-01 00:08:24            1.0
# 2016-01-01 00:09:11            1.0

# %%
# Creating a dataframe that consists of the frequency of each kind of incident grouped by the neighborhood (arrondiement)
fire_df = fire_df.reset_index()
fire_type_arron = pd.DataFrame([fire_df.nom_arrond,fire_df.description_groupe]).transpose()
fire_type_arron['freq'] = 0
fire_type_arron_freq = fire_type_arron.groupby([fire_type_arron.nom_arrond,fire_type_arron.description_groupe]).freq.count()
fire_type_arron_freq = pd.DataFrame(fire_type_arron_freq)

fire_type_arron.head()
fire_type_arron_freq = fire_type_arron_freq.reset_index()
fire_type_arron_freq.head()
# Out:
#                 nom_arrond           description_groupe  freq
# 0  Ahuntsic / Cartierville            Alarmes-incendies   767
# 1  Ahuntsic / Cartierville             Autres incendies   209
# 2  Ahuntsic / Cartierville  Fausses alertes/annulations     8
# 3  Ahuntsic / Cartierville       Incendies de bâtiments    76
# 4  Ahuntsic / Cartierville            Premier répondant  5117

# %%
#Import Census Data for 2016
census = pd.read_csv('census2016.csv')
census.head()
# Out:
#                Unnamed: 0 AGGLOMÉRATION DE MONTRÉAL Ville de Montréal  \
# 0          population2016                 1,942,044         1,704,694
# 1          population2011                 1,886,481         1,649,519
# 2  percVariation2011_2016                       2.9               3.3
# 3                area_km2                     499.1             365.2
# 4                 density                     3,891             4,668
#
#   Ahuntsic-Cartierville   Anjou Côte-des-Neiges–Notre-Dame-de-Grâce Lachine  \
# 0               134,245  42,796                             166,520  44,489
# 1               126,891  41,928                             165,031  41,616
# 2                   5.8     2.1                                 0.9     6.9
# 3                  24.2    13.7                                21.4    17.7
# 4                 5,556   3,128                               7,767   2,511
#
#   LaSalle Le Plateau-Mont-Royal Le Sud-Ouest    ...     Dorval Hampstead  \
# 0  76,853               104,000       78,151    ...     18,980     6,973
# 1  74,276               100,390       71,546    ...     18,208     7,153
# 2     3.5                   3.6          9.2    ...        4.2      -2.5
# 3    16.3                   8.1         15.7    ...       20.9       1.8
# 4   4,724                12,792        4,984    ...        910     3,904
#
#   Kirkland Montréal-Est Montréal-Ouest Mont-Royal Pointe-Claire  \
# 0   20,151        3,850          5,050     20,276        31,380
# 1   21,253        3,728          5,085     19,503        30,790
# 2     -5.2          3.3           -0.7        4.0           1.9
# 3      9.6         12.5            1.4        7.6          18.8
# 4    2,094          309          3,597      2,652         1,666
#
#   Sainte-Anne-de-Bellevue Senneville Westmount
# 0                   4,958        921    20,312
# 1                   5,073        920    19,931
# 2                    -2.3        0.1       1.9
# 3                    10.6        7.5       4.0
# 4                     470        123     5,055
#
# [5 rows x 36 columns]

# %%
# Correcting the names of the neighbourhood so it matches with the neighborhoods in fire data.
census.columns = ['Unnamed: 0', 'AGGLOMÉRATION DE MONTRÉAL', 'Ville de Montréal','Ahuntsic / Cartierville','Anjou','Côte-des-Neiges / Notre-Dame-de-Grâce','Lachine', 'Lasalle','Plateau Mont-Royal','Sud-Ouest',"L'Ile-Bizard / Ste-Geneviève",'Mercier / Hochelaga-Maisonneuve','Montréal-Nord','Outremont','Pierrefonds / Roxboro','Rivière-des-Prairies / Pointe-aux-Trembles','Rosemont / Petite-Patrie','Saint-Laurent','Saint-Léonard','Verdun','Ville-Marie','Villeray / St-Michel / Parc Extension',"Baie-D'Urfé",'Beaconsfield',
       'Côte-Saint-Luc', 'Dollard-Des Ormeaux', 'Dorval', 'Hampstead',
       'Kirkland', 'Montréal-Est', 'Montréal-Ouest', 'Mont-Royal',
       'Pointe-Claire', 'Sainte-Anne-de-Bellevue', 'Senneville', 'Westmount']

# %%
census = census.transpose()
columList = census.iloc[0,:].tolist()
census.columns = columList
census = census.iloc[2:,:]
census.head()
census = census.iloc[1:,:]
census.head()
# Out:
#                                       population2016 population2011  \
# Ahuntsic / Cartierville                      134,245        126,891
# Anjou                                         42,796         41,928
# Côte-des-Neiges / Notre-Dame-de-Grâce        166,520        165,031
# Lachine                                       44,489         41,616
# Lasalle                                       76,853         74,276
#
#                                       percVariation2011_2016 area_km2 density  \
# Ahuntsic / Cartierville                                  5.8     24.2   5,556
# Anjou                                                    2.1     13.7   3,128
# Côte-des-Neiges / Notre-Dame-de-Grâce                    0.9     21.4   7,767
# Lachine                                                  6.9     17.7   2,511
# Lasalle                                                  3.5     16.3   4,724
#
#                                       population_total population_0_4yrs  \
# Ahuntsic / Cartierville                        134,245             8,610
# Anjou                                           42,800             2,440
# Côte-des-Neiges / Notre-Dame-de-Grâce          166,515             9,495
# Lachine                                         44,485             2,535
# Lasalle                                         76,860             4,455
#
#                                       population_5_9yrs population_10_14yrs  \
# Ahuntsic / Cartierville                           7,855               6,280
# Anjou                                             2,605               2,210
# Côte-des-Neiges / Notre-Dame-de-Grâce             9,285               8,060
# Lachine                                           2,470               2,190
# Lasalle                                           4,290               3,735
#
#                                       population_15_19yrs  \
# Ahuntsic / Cartierville                             6,435
# Anjou                                               2,095
# Côte-des-Neiges / Notre-Dame-de-Grâce               9,250
# Lachine                                             2,245
# Lasalle                                             3,950
#
#                                                    ...               \
# Ahuntsic / Cartierville                            ...
# Anjou                                              ...
# Côte-des-Neiges / Notre-Dame-de-Grâce              ...
# Lachine                                            ...
# Lasalle                                            ...
#
#                                       houseHoldIncome_2015_45K_50K  \
# Ahuntsic / Cartierville                                      2,990
# Anjou                                                        1,105
# Côte-des-Neiges / Notre-Dame-de-Grâce                        3,605
# Lachine                                                      1,020
# Lasalle                                                      2,075
#
#                                       houseHoldIncome_2015_50K_60K  \
# Ahuntsic / Cartierville                                      5,485
# Anjou                                                        1,955
# Côte-des-Neiges / Notre-Dame-de-Grâce                        6,290
# Lachine                                                      1,850
# Lasalle                                                      3,450
#
#                                       houseHoldIncome_2015_60K_70K  \
# Ahuntsic / Cartierville                                      4,540
# Anjou                                                        1,575
# Côte-des-Neiges / Notre-Dame-de-Grâce                        5,210
# Lachine                                                      1,410
# Lasalle                                                      2,790
#
#                                       houseHoldIncome_2015_70K_80K  \
# Ahuntsic / Cartierville                                      3,500
# Anjou                                                        1,335
# Côte-des-Neiges / Notre-Dame-de-Grâce                        4,030
# Lachine                                                      1,175
# Lasalle                                                      2,125
#
#                                       houseHoldIncome_2015_80K_90K  \
# Ahuntsic / Cartierville                                      2,880
# Anjou                                                        1,070
# Côte-des-Neiges / Notre-Dame-de-Grâce                        3,305
# Lachine                                                      1,065
# Lasalle                                                      1,775
#
#                                       houseHoldIncome_2015_90K_100K  \
# Ahuntsic / Cartierville                                       2,460
# Anjou                                                           745
# Côte-des-Neiges / Notre-Dame-de-Grâce                         2,460
# Lachine                                                         870
# Lasalle                                                       1,465
#
#                                       houseHoldIncome_2015_100K_125K  \
# Ahuntsic / Cartierville                                        3,895
# Anjou                                                          1,415
# Côte-des-Neiges / Notre-Dame-de-Grâce                          4,085
# Lachine                                                        1,525
# Lasalle                                                        2,540
#
#                                       houseHoldIncome_2015_125K_150K  \
# Ahuntsic / Cartierville                                        2,295
# Anjou                                                            815
# Côte-des-Neiges / Notre-Dame-de-Grâce                          2,705
# Lachine                                                          930
# Lasalle                                                        1,400
#
#                                       houseHoldIncome_2015_150K_200K  \
# Ahuntsic / Cartierville                                        2,610
# Anjou                                                            720
# Côte-des-Neiges / Notre-Dame-de-Grâce                          2,775
# Lachine                                                          905
# Lasalle                                                        1,160
#
#                                       houseHoldIncome_2015_200KPlus
# Ahuntsic / Cartierville                                       2,465
# Anjou                                                           565
# Côte-des-Neiges / Notre-Dame-de-Grâce                         3,410
# Lachine                                                         745
# Lasalle                                                         635
#
# [5 rows x 171 columns]

# %%
census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, Ahuntsic / Cartierville to Westmount
# Columns: 171 entries, population2016 to houseHoldIncome_2015_200KPlus
# dtypes: object(171)
# memory usage: 44.3+ KB

# %%
# change the data type of the columns from Object to float
for i in range(census.columns.size) :
  census[census.columns[i]] = census[census.columns[i]].str.replace(",","").astype(float)
census.reset_index()
  
census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Columns: 172 entries, index to houseHoldIncome_2015_200KPlus
# dtypes: float64(171), object(1)
# memory usage: 44.4+ KB

# %%
# Merging the fire incident frequency dataset with census dataset
fire_cen_type_aron_freq = pd.merge(left=fire_type_arron_freq, right=census, left_on=fire_type_arron_freq.nom_arrond, right_on=census['index'], how='left')
fire_cen_type_aron_freq.head()
# Out:
#                 nom_arrond           description_groupe  freq  \
# 0  Ahuntsic / Cartierville            Alarmes-incendies   767
# 1  Ahuntsic / Cartierville             Autres incendies   209
# 2  Ahuntsic / Cartierville  Fausses alertes/annulations     8
# 3  Ahuntsic / Cartierville       Incendies de bâtiments    76
# 4  Ahuntsic / Cartierville            Premier répondant  5117
#
#                      index  population2016  population2011  \
# 0  Ahuntsic / Cartierville        134245.0        126891.0
# 1  Ahuntsic / Cartierville        134245.0        126891.0
# 2  Ahuntsic / Cartierville        134245.0        126891.0
# 3  Ahuntsic / Cartierville        134245.0        126891.0
# 4  Ahuntsic / Cartierville        134245.0        126891.0
#
#    percVariation2011_2016  area_km2  density  population_total  \
# 0                     5.8      24.2   5556.0          134245.0
# 1                     5.8      24.2   5556.0          134245.0
# 2                     5.8      24.2   5556.0          134245.0
# 3                     5.8      24.2   5556.0          134245.0
# 4                     5.8      24.2   5556.0          134245.0
#
#                ...                houseHoldIncome_2015_45K_50K  \
# 0              ...                                      2990.0
# 1              ...                                      2990.0
# 2              ...                                      2990.0
# 3              ...                                      2990.0
# 4              ...                                      2990.0
#
#    houseHoldIncome_2015_50K_60K  houseHoldIncome_2015_60K_70K  \
# 0                        5485.0                        4540.0
# 1                        5485.0                        4540.0
# 2                        5485.0                        4540.0
# 3                        5485.0                        4540.0
# 4                        5485.0                        4540.0
#
#    houseHoldIncome_2015_70K_80K  houseHoldIncome_2015_80K_90K  \
# 0                        3500.0                        2880.0
# 1                        3500.0                        2880.0
# 2                        3500.0                        2880.0
# 3                        3500.0                        2880.0
# 4                        3500.0                        2880.0
#
#    houseHoldIncome_2015_90K_100K  houseHoldIncome_2015_100K_125K  \
# 0                         2460.0                          3895.0
# 1                         2460.0                          3895.0
# 2                         2460.0                          3895.0
# 3                         2460.0                          3895.0
# 4                         2460.0                          3895.0
#
#    houseHoldIncome_2015_125K_150K  houseHoldIncome_2015_150K_200K  \
# 0                          2295.0                          2610.0
# 1                          2295.0                          2610.0
# 2                          2295.0                          2610.0
# 3                          2295.0                          2610.0
# 4                          2295.0                          2610.0
#
#    houseHoldIncome_2015_200KPlus
# 0                         2465.0
# 1                         2465.0
# 2                         2465.0
# 3                         2465.0
# 4                         2465.0
#
# [5 rows x 175 columns]

# %%
fire_cen_type_aron_freq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119 entries, 0 to 118
# Columns: 175 entries, nom_arrond to houseHoldIncome_2015_200KPlus
# dtypes: float64(171), int64(1), object(3)
# memory usage: 163.6+ KB

# %%
fire_cen_type_aron_freq.dropna(inplace=True)
fire_cen_type_aron_freq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 113 entries, 0 to 118
# Columns: 175 entries, nom_arrond to houseHoldIncome_2015_200KPlus
# dtypes: float64(171), int64(1), object(3)
# memory usage: 155.4+ KB

# %%
# Calculating the pearson correlation matrix between all the census feature and the frequency of the diffrent types of incidents for the corresponding neighborhoods.

c_matrix = pd.DataFrame(index=fire_cen_type_aron_freq.columns[4:175],columns=fire_cen_type_aron_freq.description_groupe.unique().tolist())
types = fire_cen_type_aron_freq.description_groupe.unique().tolist()

for type in range(len(types)) :
  relevant_rows = fire_cen_type_aron_freq[fire_cen_type_aron_freq.description_groupe == types[type]]
  for j in range(4,175) :
    c_matrix.iloc[j-4, type] = np.corrcoef(relevant_rows.freq,relevant_rows.iloc[:,j])[0][1] 

for i in range(0,6) :
  if c_matrix[c_matrix.columns[i]].dtype == object :
    c_matrix[c_matrix.columns[i]] = c_matrix[c_matrix.columns[i]].astype('float')    
c_matrix
# Out:
#                                    Alarmes-incendies  Autres incendies  \
# population2016                              0.594237          0.730211
# population2011                              0.579671          0.714180
# percVariation2011_2016                      0.261614          0.266747
# area_km2                                    0.056356          0.308269
# density                                     0.385716          0.309591
# population_total                            0.594246          0.730215
# population_0_4yrs                           0.401271          0.544584
# population_5_9yrs                           0.294770          0.424263
# population_10_14yrs                         0.254808          0.379404
# population_15_19yrs                         0.411506          0.498722
# population_20_24yrs                         0.830184          0.776191
# population_25_29yrs                         0.787987          0.813614
# population_30_34yrs                         0.712776          0.781280
# population_35_39yrs                         0.626871          0.729706
# population_40_44yrs                         0.550779          0.665135
# population_45_49yrs                         0.482559          0.642283
# population_50_54yrs                         0.461053          0.703886
# population_55_59yrs                         0.442774          0.729553
# population_60_64yrs                         0.485748          0.747253
# population_65_69yrs                         0.517177          0.724576
# population_70_74yrs                         0.476763          0.683893
# population_75_79yrs                         0.369484          0.565321
# population_80_84yrs                         0.313222          0.498125
# population_85_89yrs                         0.333053          0.513155
# population_90_94yrs                         0.405444          0.510865
# population_95_99yrs                         0.446057          0.477967
# population_100yrs_over                      0.356496          0.403357
# mean_age_total                             -0.423565         -0.235397
# median_age_total                           -0.669136         -0.487799
# males_total                                 0.639530          0.771102
# ...                                              ...               ...
# education_highschool                        0.487690          0.708093
# education_postSecondary                     0.742302          0.754034
# education_college                           0.574970          0.717944
# education_university                        0.821438          0.649651
# education_university_Bac                    0.808649          0.688159
# education_university_postgraduate           0.796390          0.625866
# education_university_medicine               0.841776          0.488692
# education_university_masters                0.813688          0.610700
# education_university_doctoral               0.755422          0.444351
# mean_houseHoldIncome_2015                  -0.315638         -0.513149
# median_houseHoldIncome_2015                -0.586245         -0.647681
# houseHoldIncome_2015_less5K                 0.959382          0.700871
# houseHoldIncome_2015_5K_10K                 0.818554          0.724031
# houseHoldIncome_2015_10K_15K                0.763746          0.779222
# houseHoldIncome_2015_15K_20K                0.712787          0.758338
# houseHoldIncome_2015_20K_25K                0.639551          0.718560
# houseHoldIncome_2015_25K_30K                0.603728          0.701724
# houseHoldIncome_2015_30K_35K                0.592169          0.731292
# houseHoldIncome_2015_35K_40K                0.541802          0.712862
# houseHoldIncome_2015_40K_45K                0.579431          0.735557
# houseHoldIncome_2015_45K_50K                0.560490          0.730390
# houseHoldIncome_2015_50K_60K                0.545890          0.731949
# houseHoldIncome_2015_60K_70K                0.556305          0.741006
# houseHoldIncome_2015_70K_80K                0.562895          0.776878
# houseHoldIncome_2015_80K_90K                0.576832          0.785148
# houseHoldIncome_2015_90K_100K               0.506933          0.770791
# houseHoldIncome_2015_100K_125K              0.496241          0.758985
# houseHoldIncome_2015_125K_150K              0.561243          0.755008
# houseHoldIncome_2015_150K_200K              0.597851          0.694259
# houseHoldIncome_2015_200KPlus               0.726944          0.431872
#
#                                    Fausses alertes/annulations  \
# population2016                                        0.698660
# population2011                                        0.687729
# percVariation2011_2016                                0.207886
# area_km2                                              0.003670
# density                                               0.524093
# population_total                                      0.698650
# population_0_4yrs                                     0.502154
# population_5_9yrs                                     0.361132
# population_10_14yrs                                   0.301254
# population_15_19yrs                                   0.424741
# population_20_24yrs                                   0.775364
# population_25_29yrs                                   0.824678
# population_30_34yrs                                   0.792830
# population_35_39yrs                                   0.736063
# population_40_44yrs                                   0.630291
# population_45_49yrs                                   0.578675
# population_50_54yrs                                   0.643874
# population_55_59yrs                                   0.672382
# population_60_64yrs                                   0.715188
# population_65_69yrs                                   0.683605
# population_70_74yrs                                   0.640906
# population_75_79yrs                                   0.500471
# population_80_84yrs                                   0.486989
# population_85_89yrs                                   0.530171
# population_90_94yrs                                   0.600096
# population_95_99yrs                                   0.596138
# population_100yrs_over                                0.531533
# mean_age_total                                       -0.234854
# median_age_total                                     -0.561569
# males_total                                           0.729083
# ...                                                        ...
# education_highschool                                  0.612706
# education_postSecondary                               0.764608
# education_college                                     0.682380
# education_university                                  0.690946
# education_university_Bac                              0.704314
# education_university_postgraduate                     0.672142
# education_university_medicine                         0.508425
# education_university_masters                          0.679619
# education_university_doctoral                         0.556359
# mean_houseHoldIncome_2015                            -0.430176
# median_houseHoldIncome_2015                          -0.641686
# houseHoldIncome_2015_less5K                           0.692707
# houseHoldIncome_2015_5K_10K                           0.806451
# houseHoldIncome_2015_10K_15K                          0.868706
# houseHoldIncome_2015_15K_20K                          0.808961
# houseHoldIncome_2015_20K_25K                          0.785671
# houseHoldIncome_2015_25K_30K                          0.752974
# houseHoldIncome_2015_30K_35K                          0.741852
# houseHoldIncome_2015_35K_40K                          0.745365
# houseHoldIncome_2015_40K_45K                          0.763040
# houseHoldIncome_2015_45K_50K                          0.738529
# houseHoldIncome_2015_50K_60K                          0.719696
# houseHoldIncome_2015_60K_70K                          0.733025
# houseHoldIncome_2015_70K_80K                          0.758815
# houseHoldIncome_2015_80K_90K                          0.745275
# houseHoldIncome_2015_90K_100K                         0.725355
# houseHoldIncome_2015_100K_125K                        0.700585
# houseHoldIncome_2015_125K_150K                        0.691915
# houseHoldIncome_2015_150K_200K                        0.657025
# houseHoldIncome_2015_200KPlus                         0.447971
#
#                                    Incendies de bâtiments  Premier répondant  \
# population2016                                   0.881374           0.733402
# population2011                                   0.875690           0.722340
# percVariation2011_2016                           0.098599           0.158194
# area_km2                                         0.029435           0.139941
# density                                          0.625357           0.382995
# population_total                                 0.881384           0.733417
# population_0_4yrs                                0.749297           0.569464
# population_5_9yrs                                0.643252           0.445244
# population_10_14yrs                              0.590875           0.385804
# population_15_19yrs                              0.695722           0.510917
# population_20_24yrs                              0.943061           0.805355
# population_25_29yrs                              0.956819           0.820193
# population_30_34yrs                              0.945498           0.779855
# population_35_39yrs                              0.911167           0.728092
# population_40_44yrs                              0.852246           0.666341
# population_45_49yrs                              0.791251           0.643191
# population_50_54yrs                              0.785101           0.671986
# population_55_59yrs                              0.769585           0.679641
# population_60_64yrs                              0.792511           0.709114
# population_65_69yrs                              0.773533           0.710118
# population_70_74yrs                              0.704628           0.693859
# population_75_79yrs                              0.595432           0.611856
# population_80_84yrs                              0.551854           0.550138
# population_85_89yrs                              0.568362           0.552913
# population_90_94yrs                              0.633716           0.551961
# population_95_99yrs                              0.632711           0.510627
# population_100yrs_over                           0.535548           0.433482
# mean_age_total                                  -0.533775          -0.230784
# median_age_total                                -0.683124          -0.508612
# males_total                                      0.906160           0.773774
# ...                                                   ...                ...
# education_highschool                             0.788806           0.698690
# education_postSecondary                          0.915286           0.749217
# education_college                                0.838856           0.699629
# education_university                             0.859630           0.653511
# education_university_Bac                         0.880690           0.685119
# education_university_postgraduate                0.837966           0.648286
# education_university_medicine                    0.619179           0.520627
# education_university_masters                     0.829663           0.613151
# education_university_doctoral                    0.728085           0.470560
# mean_houseHoldIncome_2015                       -0.521722          -0.545186
# median_houseHoldIncome_2015                     -0.702165          -0.736604
# houseHoldIncome_2015_less5K                      0.730834           0.766449
# houseHoldIncome_2015_5K_10K                      0.955812           0.785538
# houseHoldIncome_2015_10K_15K                     0.958655           0.830082
# houseHoldIncome_2015_15K_20K                     0.964731           0.819299
# houseHoldIncome_2015_20K_25K                     0.929263           0.787908
# houseHoldIncome_2015_25K_30K                     0.922713           0.768863
# houseHoldIncome_2015_30K_35K                     0.907584           0.773151
# houseHoldIncome_2015_35K_40K                     0.871594           0.754583
# houseHoldIncome_2015_40K_45K                     0.893213           0.766845
# houseHoldIncome_2015_45K_50K                     0.883728           0.759836
# houseHoldIncome_2015_50K_60K                     0.868279           0.738672
# houseHoldIncome_2015_60K_70K                     0.862983           0.733821
# houseHoldIncome_2015_70K_80K                     0.854827           0.747847
# houseHoldIncome_2015_80K_90K                     0.854108           0.736401
# houseHoldIncome_2015_90K_100K                    0.799645           0.687803
# houseHoldIncome_2015_100K_125K                   0.753484           0.652047
# houseHoldIncome_2015_125K_150K                   0.752805           0.629535
# houseHoldIncome_2015_150K_200K                   0.694713           0.564763
# houseHoldIncome_2015_200KPlus                    0.505837           0.389095
#
#                                    Sans incendie
# population2016                          0.760297
# population2011                          0.748479
# percVariation2011_2016                  0.204106
# area_km2                                0.019796
# density                                 0.558991
# population_total                        0.760305
# population_0_4yrs                       0.572064
# population_5_9yrs                       0.451541
# population_10_14yrs                     0.399481
# population_15_19yrs                     0.548609
# population_20_24yrs                     0.942756
# population_25_29yrs                     0.928420
# population_30_34yrs                     0.872010
# population_35_39yrs                     0.799722
# population_40_44yrs                     0.717406
# population_45_49yrs                     0.643455
# population_50_54yrs                     0.633425
# population_55_59yrs                     0.619785
# population_60_64yrs                     0.659478
# population_65_69yrs                     0.666342
# population_70_74yrs                     0.608282
# population_75_79yrs                     0.485773
# population_80_84yrs                     0.433866
# population_85_89yrs                     0.453724
# population_90_94yrs                     0.529898
# population_95_99yrs                     0.553634
# population_100yrs_over                  0.451871
# mean_age_total                         -0.499451
# median_age_total                       -0.728595
# males_total                             0.800082
# ...                                          ...
# education_highschool                    0.649375
# education_postSecondary                 0.874185
# education_college                       0.729623
# education_university                    0.899017
# education_university_Bac                0.897476
# education_university_postgraduate       0.868549
# education_university_medicine           0.792446
# education_university_masters            0.886530
# education_university_doctoral           0.808636
# mean_houseHoldIncome_2015              -0.429308
# median_houseHoldIncome_2015            -0.679589
# houseHoldIncome_2015_less5K             0.921354
# houseHoldIncome_2015_5K_10K             0.944109
# houseHoldIncome_2015_10K_15K            0.909814
# houseHoldIncome_2015_15K_20K            0.873928
# houseHoldIncome_2015_20K_25K            0.810817
# houseHoldIncome_2015_25K_30K            0.785714
# houseHoldIncome_2015_30K_35K            0.771289
# houseHoldIncome_2015_35K_40K            0.731269
# houseHoldIncome_2015_40K_45K            0.763293
# houseHoldIncome_2015_45K_50K            0.746356
# houseHoldIncome_2015_50K_60K            0.730752
# houseHoldIncome_2015_60K_70K            0.738828
# houseHoldIncome_2015_70K_80K            0.744354
# houseHoldIncome_2015_80K_90K            0.751553
# houseHoldIncome_2015_90K_100K           0.691538
# houseHoldIncome_2015_100K_125K          0.662693
# houseHoldIncome_2015_125K_150K          0.702265
# houseHoldIncome_2015_150K_200K          0.698694
# houseHoldIncome_2015_200KPlus           0.671758
#
# [171 rows x 6 columns]

# %%
import seaborn as sns
plt.figure(figsize=(20,50))
sns.heatmap(c_matrix, 
            xticklabels=c_matrix.columns.values,
            yticklabels=c_matrix.index.values)

# %%
factor_groups = ['population','singleParentHouseholds','Couple','household','houseType','houseSize','houseAge','residentLanguage','education','houseHoldIncome']

for group in factor_groups:
  c_matrix_group = c_matrix.loc[c_matrix.index.str.startswith(group)] 
  print('')  
  import seaborn as sns
  plt.figure(figsize=(17,12))

  plt.subplots_adjust(left=0.1, right=0.9,top=0.5,bottom=0.1)
  sns.heatmap(c_matrix_group, 
              xticklabels=c_matrix_group.columns.values,
              yticklabels=c_matrix_group.index.values)

# %% [markdown]
# We can see some interesting correlation in the figures above. For example
# 1. High correlation  between "Incendies de batiments" and the low income house holds , old houses, and rented houses
# 2. High Correlation of incidents with "couples_nokids".
